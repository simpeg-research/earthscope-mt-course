# %% [markdown]
# # 2D Inversion of Yellowstone Data
#
# Here we will show an example of how to invert profile data in 2D.  These data were collected with the purpose of a 2D inversion.
#
# First load in the data.  These data are from stations that starts with "SR2" or from the survey 'Yellowstone-Snake_River_Plain'

# %%
from pathlib import Path
import numpy as np
from mtpy import MTCollection
from mtpy.modeling.simpeg.recipes import Simpeg2D

# %%
# %%time
with MTCollection() as mc:
    mc.open_collection(Path().cwd().parent.parent.joinpath("data", "transfer_functions", "yellowstone_mt_collection.h5"))
    #mc.working_dataframe = mc.master_dataframe[mc.master_dataframe.station.str.startswith("SR2")]
    mc.working_dataframe = mc.master_dataframe[mc.master_dataframe.survey == 'Yellowstone-Snake_River_Plain']
    profile_mt_data = mc.to_mt_data()
# Out:
# 24:10:15T15:28:57 | INFO | line:777 |mth5.mth5 | close_mth5 | Flushing and closing c:\Users\jpeacock\OneDrive - DOI\Documents\GitHub\iris-mt-course-2022\data\transfer_functions\yellowstone_mt_collection.h5
# CPU times: total: 36.6 s
# Wall time: 54.9 s

# %% [markdown]
# ## Plot Stations
#
# We want to make sure we got the data we expected. Now notice that there are 2 profiles, one striking northwest and one striking northeast.

# %%
station_plot = profile_mt_data.plot_stations()

# %% [markdown]
# ## Pick a profile line
#
# Now that we see there are 2 profiles lets creat a line that trends northwest through the dense station coverage.
#
# This data is in UTM Zone WGS84 12N (EPSG: 32612).  We need this estimate distances from a profile line and for modeling.
#
# Here we sent the UTM coordinate system.

# %%
profile_mt_data.utm_epsg = 32612

# %% [markdown]
# Now we need to set a profile line.  From the map it looks like x1, y1 = (-111, 42.3) and x2, y2 = (-114.5, 44.55). Lets set that as our profile line and pick any station within 10km of the line.

# %%
profile = profile_mt_data.get_profile(-111, 42.1, -114.5, 44.55, 15000)

# %%
profile_stations_plot = profile.plot_stations()

# %% [markdown]
# ## Interpolate data onto the same period map
#
# It is important to use bounds_error=False, which will put Nan where data cannot be interpolated. Interpolate onto a period range that keeps the mesh small.  decrease the first number to get shorter periods. This is long period data so the smallest period is nominally 1 second but the first good period is usually 10 seconds.

# %%
profile.interpolate(np.logspace(1, 4, 5), inplace=True, bounds_error=False)

# %%
# 5) set data modeling errors, set an error floor of 5 % for the impedance
profile.z_model_error.error_value = 5
profile.z_model_error.error_type = "percent"
profile.z_model_error
# Out:
# Model Errors:
# --------------------
# 	error_type:    percent
# 	error_value:   0.05
# 	floor:         True
# 	mode:          impedance

# %%
profile.compute_model_errors()

# %% [markdown]
# ## Strike direction
#
# Now with 2D inversions we need to maximize the components to be parallel and perpendicular to geoelectrical strike.  We can estimate the geoelectrical strike and plot per period.

# %%
strike_plot = profile.plot_strike(plot_type=1)
# Out:
# 24:10:15T15:53:36 | INFO | line:765 |mtpy.imaging.plot_strike | _plot_per_period | Note: North is assumed to be 0 and the strike angle is measuredclockwise positive.

# %% [markdown]
# From the plot we can see that there are few different strike angles.  And this is where you need to make an educated decision for which angle you want to rotate your data to maximize the TE and TM modes.  There is a dominant shallow strike of around N70E, then there is a deeper strike of around N20E and an even deeper strike of around N10E.  So you could do a couple of things. You could rotate to an average, mean, invert just a few periods at each strike angle, etc.  This is why 2D modeling is difficult.  Below is an example of how to rotate the data.
#
# ### Data Rotation
#
# Rotation is clockwise into strike, rotating North into East.  So if you have a strike angle of 10 you want to rotate your data 10 degrees to maximize the TE and TM modes.

# %%
rotate_profile_n20e = profile.rotate(20, inplace=False)
# Out:
# 24:10:15T15:59:46 | INFO | line:266 |mtpy.core.mt | rotate | Rotated transfer function by: 20.000 degrees clockwise in reference frame NED.
# 24:10:15T15:59:47 | INFO | line:266 |mtpy.core.mt | rotate | Rotated transfer function by: 20.000 degrees clockwise in reference frame NED.
# 24:10:15T15:59:47 | INFO | line:266 |mtpy.core.mt | rotate | Rotated transfer function by: 20.000 degrees clockwise in reference frame NED.
# 24:10:15T15:59:48 | INFO | line:266 |mtpy.core.mt | rotate | Rotated transfer function by: 20.000 degrees clockwise in reference frame NED.
# 24:10:15T15:59:48 | INFO | line:266 |mtpy.core.mt | rotate | Rotated transfer function by: 20.000 degrees clockwise in reference frame NED.
# 24:10:15T15:59:49 | INFO | line:266 |mtpy.core.mt | rotate | Rotated transfer function by: 20.000 degrees clockwise in reference frame NED.
# 24:10:15T15:59:49 | INFO | line:266 |mtpy.core.mt | rotate | Rotated transfer function by: 20.000 degrees clockwise in reference frame NED.
# 24:10:15T15:59:49 | INFO | line:266 |mtpy.core.mt | rotate | Rotated transfer function by: 20.000 degrees clockwise in reference frame NED.
# 24:10:15T15:59:50 | INFO | line:266 |mtpy.core.mt | rotate | Rotated transfer function by: 20.000 degrees clockwise in reference frame NED.
# 24:10:15T15:59:50 | INFO | line:266 |mtpy.core.mt | rotate | Rotated transfer function by: 20.000 degrees clockwise in reference frame NED.
# 24:10:15T15:59:51 | INFO | line:266 |mtpy.core.mt | rotate | Rotated transfer function by: 20.000 degrees clockwise in reference frame NED.
# 24:10:15T15:59:51 | INFO | line:266 |mtpy.core.mt | rotate | Rotated transfer function by: 20.000 degrees clockwise in reference frame NED.
# 24:10:15T15:59:51 | INFO | line:266 |mtpy.core.mt | rotate | Rotated transfer function by: 20.000 degrees clockwise in reference frame NED.
# 24:10:15T15:59:52 | INFO | line:266 |mtpy.core.mt | rotate | Rotated transfer function by: 20.000 degrees clockwise in reference frame NED.
# 24:10:15T15:59:52 | INFO | line:266 |mtpy.core.mt | rotate | Rotated transfer function by: 20.000 degrees clockwise in reference frame NED.
# 24:10:15T15:59:52 | INFO | line:266 |mtpy.core.mt | rotate | Rotated transfer function by: 20.000 degrees clockwise in reference frame NED.
# 24:10:15T15:59:53 | INFO | line:266 |mtpy.core.mt | rotate | Rotated transfer function by: 20.000 degrees clockwise in reference frame NED.
# 24:10:15T15:59:53 | INFO | line:266 |mtpy.core.mt | rotate | Rotated transfer function by: 20.000 degrees clockwise in reference frame NED.
# 24:10:15T15:59:53 | INFO | line:266 |mtpy.core.mt | rotate | Rotated transfer function by: 20.000 degrees clockwise in reference frame NED.
# 24:10:15T15:59:54 | INFO | line:266 |mtpy.core.mt | rotate | Rotated transfer function by: 20.000 degrees clockwise in reference frame NED.
# 24:10:15T15:59:54 | INFO | line:266 |mtpy.core.mt | rotate | Rotated transfer function by: 20.000 degrees clockwise in reference frame NED.
# 24:10:15T15:59:54 | INFO | line:266 |mtpy.core.mt | rotate | Rotated transfer function by: 20.000 degrees clockwise in reference frame NED.
# 24:10:15T15:59:55 | INFO | line:266 |mtpy.core.mt | rotate | Rotated transfer function by: 20.000 degrees clockwise in reference frame NED.
# 24:10:15T15:59:55 | INFO | line:266 |mtpy.core.mt | rotate | Rotated transfer function by: 20.000 degrees clockwise in reference frame NED.
# 24:10:15T15:59:55 | INFO | line:266 |mtpy.core.mt | rotate | Rotated transfer function by: 20.000 degrees clockwise in reference frame NED.
# 24:10:15T15:59:56 | INFO | line:266 |mtpy.core.mt | rotate | Rotated transfer function by: 20.000 degrees clockwise in reference frame NED.
# 24:10:15T15:59:56 | INFO | line:266 |mtpy.core.mt | rotate | Rotated transfer function by: 20.000 degrees clockwise in reference frame NED.
# 24:10:15T15:59:56 | INFO | line:266 |mtpy.core.mt | rotate | Rotated transfer function by: 20.000 degrees clockwise in reference frame NED.
# 24:10:15T15:59:57 | INFO | line:266 |mtpy.core.mt | rotate | Rotated transfer function by: 20.000 degrees clockwise in reference frame NED.

# %%
rotated_strike_plot = rotate_profile_n20e.plot_strike(plot_type=1)
# Out:
# 24:10:15T16:00:40 | INFO | line:765 |mtpy.imaging.plot_strike | _plot_per_period | Note: North is assumed to be 0 and the strike angle is measuredclockwise positive.

# %% [markdown]
# ## Run 2D inversion
#
# Now use a somewhat standard recipe to invert the data.  User has lots of control of parameters for mesh building, inversion norms, smallness, etc.  This recipe is meant as a convenience object.  For advanced users and those who want to fully understand the Simpeg workflow should build their own recipe.
#
# Here the input data is a Pandas Dataframe.  There is a method in MTData to create a Simpeg Data object.
#
# Obviously, need to play around with mesh parameters.

# %%
simpeg_2d = Simpeg2D(
    rotate_profile_n20e.to_dataframe(impedance_units="ohm"),
    mesh_kwargs={},
    data_kwargs={},
    max_iterations=10, 
    )

# %%
print(simpeg_2d)
# Out:
# Attributes:
# 	air_conductivity: 1e-08
# 	alpha_s: 1e-05
# 	alpha_y: 0.2
# 	alpha_z: 1.0
# 	beta_cooling_factor: 2
# 	beta_cooling_rate: 1
# 	beta_starting_ratio: 1
# 	f_min_change: 1e-05
# 	initial_conductivity: 0.01
# 	max_iterations: 10
# 	max_iterations_cg: 30
# 	max_iterations_irls: 40
# 	minimum_gauss_newton_iterations: 1
# 	p_s: 0
# 	p_y: 0
# 	p_z: 0
# 	solver: pardiso
# 	target_misfit_chi_factor: 1
# 	use_irls: False
# Properties:
# 	active_map: InjectActiveCells(1403,622)
# 	beta_schedule: <simpeg.directives.directives.BetaSchedule object at 0x000001E53D742850>
# 	conductivity_map: ComboMap[ExpMap(1403,1403) * InjectActiveCells(1403,622)](1403,622)
# 	data_misfit: <simpeg.objective_function.ComboObjectiveFunction object at 0x000001E53D4F6910>
# 	directives: [<simpeg.directives.directives.BetaEstimate_ByEig object at 0x000001E53D4F6DF0>, <simpeg.directives.directives.BetaSchedule object at 0x000001E53D4F63D0>, <simpeg.directives.directives.SaveOutputDictEveryIteration object at 0x000001E546D54A90>, <simpeg.directives.directives.TargetMisfit object at 0x000001E53D4F6670>]
# 	exponent_map: ExpMap(1403,1403)
# 	inverse_problem: <simpeg.inverse_problem.BaseInvProblem object at 0x000001E53D4F6250>
# 	iterations: {}
# 	optimization: <simpeg.optimization.InexactGaussNewton object at 0x000001E53D4F6130>
# 	reference_model: [-4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019
#  -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019
#  -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019
#  -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019
#  -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019
#  -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019
#  -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019
#  -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019
#  -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019
#  -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019
#  -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019
#  -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019
#  -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019
#  -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019
#  -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019
#  -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019
#  -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019
#  -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019
#  -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019
#  -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019
#  -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019
#  -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019
#  -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019
#  -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019
#  -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019
#  -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019
#  -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019
#  -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019
#  -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019
#  -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019
#  -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019
#  -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019
#  -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019
#  -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019
#  -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019
#  -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019
#  -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019
#  -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019
#  -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019
#  -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019
#  -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019
#  -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019
#  -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019
#  -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019
#  -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019
#  -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019
#  -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019
#  -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019
#  -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019
#  -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019
#  -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019
#  -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019
#  -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019
#  -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019
#  -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019
#  -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019
#  -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019
#  -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019
#  -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019
#  -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019
#  -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019
#  -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019
#  -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019
#  -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019
#  -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019
#  -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019
#  -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019
#  -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019
#  -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019
#  -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019
#  -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019
#  -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019
#  -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019
#  -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019
#  -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019
#  -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019
#  -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019
#  -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019
#  -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019
#  -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019
#  -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019
#  -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019
#  -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019
#  -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019
#  -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019
#  -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019
#  -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019
#  -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019
#  -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019
#  -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019
#  -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019
#  -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019
#  -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019
#  -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019
#  -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019
#  -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019
#  -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019
#  -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019
#  -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019
#  -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019
#  -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019
#  -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019
#  -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019 -4.60517019
#  -4.60517019 -4.60517019 -4.60517019 -4.60517019]
# 	regularization: <simpeg.regularization.sparse.Sparse object at 0x000001E53D4F6850>
# 	starting_beta: <simpeg.directives.directives.BetaEstimate_ByEig object at 0x000001E53D4F6CA0>
# 	target_misfit: <simpeg.directives.directives.TargetMisfit object at 0x000001E53D4F6B80>
# 	te_data_misfit: <simpeg.data_misfit.L2DataMisfit object at 0x000001E542F21AC0>
# 	te_simulation: <simpeg.electromagnetics.natural_source.simulation.Simulation2DMagneticField object at 0x000001E53D4E00D0>
# 	tm_data_misfit: <simpeg.data_misfit.L2DataMisfit object at 0x000001E53D4E0D60>
# 	tm_simulation: <simpeg.electromagnetics.natural_source.simulation.Simulation2DElectricField object at 0x000001E53D4E0CD0>
# Methods:
# 	ax
# 	data
# 	make_mesh
# 	plot_iteration
# 	plot_tikhonov_curve
# 	quad_tree
# 	run_inversion
# 	saved_model_outputs

# %%
# %%time
inversion_output = simpeg_2d.run_inversion()
# Out:
# Running inversion with SimPEG v0.22.1
#
#                         simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                         ***Done using same Solver, and solver_opts as the Simulation2DMagneticField problem***
#
# model has any nan: 0
# ============================ Inexact Gauss Newton ============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  3.46e+00  3.13e+08  0.00e+00  3.13e+08    3.84e+08      0
#    1  1.73e+00  9.87e+07  5.42e+05  9.96e+07    5.02e+07      0
#    2  8.65e-01  1.64e+07  3.99e+06  1.98e+07    6.30e+06      0   Skip BFGS
#    3  4.32e-01  4.04e+06  9.80e+06  8.27e+06    8.27e+05      0   Skip BFGS
#    4  2.16e-01  2.10e+06  1.34e+07  5.00e+06    3.78e+05      0   Skip BFGS
#    5  1.08e-01  1.28e+06  1.68e+07  3.09e+06    2.14e+05      0   Skip BFGS
#    6  5.41e-02  7.58e+05  2.10e+07  1.90e+06    1.18e+05      0   Skip BFGS
#    7  2.70e-02  4.68e+05  2.59e+07  1.17e+06    6.48e+04      0   Skip BFGS
#    8  1.35e-02  3.01e+05  3.14e+07  7.26e+05    3.56e+04      0   Skip BFGS
#    9  6.76e-03  2.07e+05  3.77e+07  4.62e+05    1.78e+04      0   Skip BFGS
#   10  3.38e-03  1.57e+05  4.47e+07  3.08e+05    7.94e+03      0   Skip BFGS
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 1.5412e+05 <= tolF*(1+|f0|) = 3.1298e+07
# 1 : |xc-x_last| = 5.9211e+00 <= tolX*(1+|x0|) = 1.1585e+01
# 0 : |proj(x-g)-x|    = 7.9413e+03 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 7.9413e+03 <= 1e3*eps       = 1.0000e-02
# 1 : maxIter   =      10    <= iter          =     10
# ------------------------- DONE! -------------------------
# CPU times: total: 30.1 s
# Wall time: 25.8 s

# %%
simpeg_2d.plot_iteration(10, z_limits=(-50000, 500))

# %%
simpeg_2d.plot_tikhonov_curve()
