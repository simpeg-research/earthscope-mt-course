# %% [markdown]
# # MTpy Example 01
#
# ## Transfer Function Collection
#
# **Goal:** demonstrate how to build a standardized collection of tranfer functions from various file types ("EDI", "EMTFXML").
#
# **Test Data:** Yellowstone, WY, USA
#
#    - Broadband data provided by University of Washington and Oregon State University processed by Paul Bedrosian (USGS)
#    - Earthscope long period data archived at IRIS
#    - Long period data from DeGroot-Hedlin archived at IRIS
#
#
# We will build an `MTCollection` using `MTpy v2.0`.  Under the hood `MTCollection` is storing the transfer functions in an MTH5 file and using `mt_metadata` to read the transfer functions into a standardize transfer function.  We will also have a look at how to adjust some metadata so that your transfer functions can be nicely organized.  Each of these data sets were collected as different surveys and we will store them as such.  We will go survey by survey loading in the transfer functions.

# %%
from copy import deepcopy
from pathlib import Path

from mtpy import MT, MTCollection

# %% [markdown]
# ## Create Transfer Function Collection
#
# The first thing to do is to open a new `MTCollection` object.  You can call it what you want, for now we will call it `yellowstone_mt_collection`.
#
# ### Add Earthscope Data
#
# The data is provided locally, but the data are publicly available on the [IRIS EMTF SPUD](http://www.ds.iris.edu/spud/). Just draw a box around the area of interest and click `download spud bundle`.  This will give you a zip file that contains an EDI, EMTFXML, ZRR file and an image of what the response should look like.  We have copied the EMTFXML files into a single folder for convenience.
#
# ### Broadband Data
#
# First we will load in broadband transfer functions which are in EDI format. These files have no `survey.id` type information, therefore we are going to add it.  These files are stored locally on your machine, so just adjust the file path.  We will loop over each file and add in the appropriate metadata

# %%
# %%time
with MTCollection() as mc:
    mc.open_collection(
        filename=Path().cwd().parent.parent.joinpath("data", "transfer_functions", "yellowstone_mt_collection_03.h5")
    )
    # broadband data
    bb_edi_path = Path().cwd().parent.parent.joinpath("data", "transfer_functions","broadband")
    for edi_filename in mc.make_file_list(bb_edi_path, file_types=["edi"]):
        mt_object = MT(edi_filename)
        mt_object.read()

        # update the survey id
        mt_object.survey_metadata.id = "YSBB"
        mc.add_tf(mt_object)

    ## long period data from the MTArray
    earthscope_path = Path().cwd().parent.parent.joinpath("data", "transfer_functions","earthscope")
    for xml_fn in mc.make_file_list(earthscope_path, file_types=["xml"]):
        mt_object = MT(xml_fn)
        mt_object.read()
        mc.add_tf(mt_object)

        tf_df = mc.dataframe
# Out:
# 24:10:08T13:05:51 | WARNING | line:256 |mtpy.core.mt_collection | add_tf | If you are adding multiple transfer functions, suggest making a list of transfer functions first then adding the list using mt_collection.add_tf([list_of_tfs]). Otherwise adding transfer functions one by one will be slow.
# 24:10:08T13:05:51 | INFO | line:399 |mtpy.core.mt_collection | _from_mt_object | added YSBB.YNP01S
# 24:10:08T13:05:52 | WARNING | line:256 |mtpy.core.mt_collection | add_tf | If you are adding multiple transfer functions, suggest making a list of transfer functions first then adding the list using mt_collection.add_tf([list_of_tfs]). Otherwise adding transfer functions one by one will be slow.
# 24:10:08T13:05:52 | INFO | line:399 |mtpy.core.mt_collection | _from_mt_object | added YSBB.YNP02S
# 24:10:08T13:05:52 | WARNING | line:256 |mtpy.core.mt_collection | add_tf | If you are adding multiple transfer functions, suggest making a list of transfer functions first then adding the list using mt_collection.add_tf([list_of_tfs]). Otherwise adding transfer functions one by one will be slow.
# 24:10:08T13:05:52 | INFO | line:399 |mtpy.core.mt_collection | _from_mt_object | added YSBB.YNP03B
# 24:10:08T13:05:52 | WARNING | line:256 |mtpy.core.mt_collection | add_tf | If you are adding multiple transfer functions, suggest making a list of transfer functions first then adding the list using mt_collection.add_tf([list_of_tfs]). Otherwise adding transfer functions one by one will be slow.
# 24:10:08T13:05:52 | INFO | line:399 |mtpy.core.mt_collection | _from_mt_object | added YSBB.YNP04B
# 24:10:08T13:05:53 | WARNING | line:256 |mtpy.core.mt_collection | add_tf | If you are adding multiple transfer functions, suggest making a list of transfer functions first then adding the list using mt_collection.add_tf([list_of_tfs]). Otherwise adding transfer functions one by one will be slow.
# 24:10:08T13:05:53 | INFO | line:399 |mtpy.core.mt_collection | _from_mt_object | added YSBB.YNP05S
# 24:10:08T13:05:53 | WARNING | line:256 |mtpy.core.mt_collection | add_tf | If you are adding multiple transfer functions, suggest making a list of transfer functions first then adding the list using mt_collection.add_tf([list_of_tfs]). Otherwise adding transfer functions one by one will be slow.
# 24:10:08T13:05:53 | INFO | line:399 |mtpy.core.mt_collection | _from_mt_object | added YSBB.YNP06S
# 24:10:08T13:05:53 | WARNING | line:256 |mtpy.core.mt_collection | add_tf | If you are adding multiple transfer functions, suggest making a list of transfer functions first then adding the list using mt_collection.add_tf([list_of_tfs]). Otherwise adding transfer functions one by one will be slow.
# 24:10:08T13:05:53 | INFO | line:399 |mtpy.core.mt_collection | _from_mt_object | added YSBB.YNP07B
# 24:10:08T13:05:54 | WARNING | line:256 |mtpy.core.mt_collection | add_tf | If you are adding multiple transfer functions, suggest making a list of transfer functions first then adding the list using mt_collection.add_tf([list_of_tfs]). Otherwise adding transfer functions one by one will be slow.
# 24:10:08T13:05:54 | INFO | line:399 |mtpy.core.mt_collection | _from_mt_object | added YSBB.YNP08S
# 24:10:08T13:05:54 | WARNING | line:256 |mtpy.core.mt_collection | add_tf | If you are adding multiple transfer functions, suggest making a list of transfer functions first then adding the list using mt_collection.add_tf([list_of_tfs]). Otherwise adding transfer functions one by one will be slow.
# 24:10:08T13:05:54 | INFO | line:399 |mtpy.core.mt_collection | _from_mt_object | added YSBB.YNP09S
# 24:10:08T13:05:54 | WARNING | line:256 |mtpy.core.mt_collection | add_tf | If you are adding multiple transfer functions, suggest making a list of transfer functions first then adding the list using mt_collection.add_tf([list_of_tfs]). Otherwise adding transfer functions one by one will be slow.
# 24:10:08T13:05:54 | INFO | line:399 |mtpy.core.mt_collection | _from_mt_object | added YSBB.YNP10S
# 24:10:08T13:05:55 | WARNING | line:256 |mtpy.core.mt_collection | add_tf | If you are adding multiple transfer functions, suggest making a list of transfer functions first then adding the list using mt_collection.add_tf([list_of_tfs]). Otherwise adding transfer functions one by one will be slow.
# 24:10:08T13:05:55 | INFO | line:399 |mtpy.core.mt_collection | _from_mt_object | added YSBB.YNP11S
# 24:10:08T13:05:55 | WARNING | line:256 |mtpy.core.mt_collection | add_tf | If you are adding multiple transfer functions, suggest making a list of transfer functions first then adding the list using mt_collection.add_tf([list_of_tfs]). Otherwise adding transfer functions one by one will be slow.
# 24:10:08T13:05:55 | INFO | line:399 |mtpy.core.mt_collection | _from_mt_object | added YSBB.YNP13B
# 24:10:08T13:05:56 | WARNING | line:256 |mtpy.core.mt_collection | add_tf | If you are adding multiple transfer functions, suggest making a list of transfer functions first then adding the list using mt_collection.add_tf([list_of_tfs]). Otherwise adding transfer functions one by one will be slow.
# 24:10:08T13:05:56 | INFO | line:399 |mtpy.core.mt_collection | _from_mt_object | added YSBB.YNP14S
# 24:10:08T13:05:56 | WARNING | line:256 |mtpy.core.mt_collection | add_tf | If you are adding multiple transfer functions, suggest making a list of transfer functions first then adding the list using mt_collection.add_tf([list_of_tfs]). Otherwise adding transfer functions one by one will be slow.
# 24:10:08T13:05:56 | INFO | line:399 |mtpy.core.mt_collection | _from_mt_object | added YSBB.YN
| INFO | line:399 |mtpy.core.mt_collection | _from_mt_object | added Transportable_Array.IDH14
# 24:10:08T13:06:15 | WARNING | line:84 |mt_metadata.transfer_functions.io.emtfxml.metadata.helpers | _read_element | No declination in EMTF XML
# 24:10:08T13:06:16 | WARNING | line:256 |mtpy.core.mt_collection | add_tf | If you are adding multiple transfer functions, suggest making a list of transfer functions first then adding the list using mt_collection.add_tf([list_of_tfs]). Otherwise adding transfer functions one by one will be slow.
# 24:10:08T13:06:16 | WARNING | line:206 |mt_metadata.transfer_functions.tf.station | get_run | Could not find IDI10a in runs.
# 24:10:08T13:06:16 | INFO | line:399 |mtpy.core.mt_collection | _from_mt_object | added Transportable_Array.IDI10
# 24:10:08T13:06:16 | WARNING | line:84 |mt_metadata.transfer_functions.io.emtfxml.metadata.helpers | _read_element | No declination in EMTF XML
# 24:10:08T13:06:16 | WARNING | line:256 |mtpy.core.mt_collection | add_tf | If you are adding multiple transfer functions, suggest making a list of transfer functions first then adding the list using mt_collection.add_tf([list_of_tfs]). Otherwise adding transfer functions one by one will be slow.
# 24:10:08T13:06:16 | WARNING | line:206 |mt_metadata.transfer_functions.tf.station | get_run | Could not find IDI11c in runs.
# 24:10:08T13:06:17 | INFO | line:399 |mtpy.core.mt_collection | _from_mt_object | added Transportable_Array.IDI11
# 24:10:08T13:06:17 | WARNING | line:84 |mt_metadata.transfer_functions.io.emtfxml.metadata.helpers | _read_element | No declination in EMTF XML
# 24:10:08T13:06:17 | WARNING | line:256 |mtpy.core.mt_collection | add_tf | If you are adding multiple transfer functions, suggest making a list of transfer functions first then adding the list using mt_collection.add_tf([list_of_tfs]). Otherwise adding transfer functions one by one will be slow.
# 24:10:08T13:06:17 | WARNING | line:206 |mt_metadata.transfer_functions.tf.station | get_run | Could not find IDI12a in runs.
# 24:10:08T13:06:17 | INFO | line:399 |mtpy.core.mt_collection | _from_mt_object | added Transportable_Array.IDI12
# 24:10:08T13:06:18 | WARNING | line:84 |mt_metadata.transfer_functions.io.emtfxml.metadata.helpers | _read_element | No declination in EMTF XML
# 24:10:08T13:06:18 | WARNING | line:256 |mtpy.core.mt_collection | add_tf | If you are adding multiple transfer functions, suggest making a list of transfer functions first then adding the list using mt_collection.add_tf([list_of_tfs]). Otherwise adding transfer functions one by one will be slow.
# 24:10:08T13:06:18 | WARNING | line:206 |mt_metadata.transfer_functions.tf.station | get_run | Could not find IDI13a in runs.
# 24:10:08T13:06:18 | INFO | line:399 |mtpy.core.mt_collection | _from_mt_object | added Transportable_Array.IDI13
# 24:10:08T13:06:18 | WARNING | line:84 |mt_metadata.transfer_functions.io.emtfxml.metadata.helpers | _read_element | No declination in EMTF XML
# 24:10:08T13:06:19 | WARNING | line:256 |mtpy.core.mt_collection | add_tf | If you are adding multiple transfer functions, suggest making a list of transfer functions first then adding the list using mt_collection.add_tf([list_of_tfs]). Otherwise adding transfer functions one by one will be slow.
# 24:10:08T13:06:19 | WARNING | line:206 |mt_metadata.transfer_functions.tf.station | get_run | Could not find IDI14a in runs.
# 24:10:08T13:06:19 | INFO | line:399 |mtpy.core.mt_collection | _from_mt_object | added Transportable_Array.IDI14
# 24:10:08T13:06:19 | WARNING | line:256 |mtpy.core.mt_collection | add_tf | If you are adding multiple transfer functions, suggest making a list of transfer functions first then adding the list using mt_collection.add_tf([list_of_tfs]). Otherwise adding transfer functions one by one will be slow.
# 24:10:08T13:06:19 | WARNING | line:206 |mt_metadata.transfer_functions.tf.station | get_run | Could not find IDI15a in runs.
# 24:10:08T13:06:19 | WARNING | line:206 |mt_metadata.transfer_functions.tf.station | get_run | Could not find IDI15d in runs.
# 24:10:08T13:06:20 | INFO | line:399 |mtpy.core.mt_collection | _from_mt_object | added Transportable_Array.IDI15
# 24:10:08T13:06:20 | WARNING | line:84 |mt_metadata.transfer_functions.io.emtfxml.metadata.helpers | _read_element | No declination in EMTF XML
# 24:10:08T13:06:20 | WARNING | line:256 |mtpy.core.mt_collection | add_tf | If you are adding multiple transfer functions, suggest making a list of transfer functions first then adding the list using mt_collection.add_tf([list_of_tfs]). Otherwise adding transfer functions one by one will be slow.
# 24:10:08T13:06:20 | WARNING | line:206 |mt_metadata.transfer_functions.tf.station | get_run | Could not find IDI16a in runs.
# 24:10:08T13:06:20 | WARNING | line:206 |mt_metadata.transfer_functions.tf.station | get_run | Could not find IDI16b in runs.
# 24:10:08T13:06:20 | INFO | line:399 |mtpy.core.mt_collection | _from_mt_object | added Transportable_Array.IDI16
# 24:10:08T13:06:21 | WARNING | line:256 |mtpy.core.mt_collection | add_tf | If you are adding multiple transfer functions, suggest making a list of transfer functions first then adding the list using mt_collection.add_tf([list_of_tfs]). Otherwise adding transfer functions one by one will be slow.
# 24:10:08T13:06:21 | WARNING | line:206 |mt_metadata.transfer_functions.tf.station | get_run | Could not find IDJ10b in runs.
# 24:10:08T13:06:21 | INFO | line:399 |mtpy.core.mt_collection | _from_mt_object | added Transportable_Array.IDJ10
# 24:10:08T13:06:22 | WARNING | line:84 |mt_metadata.transfer_functions.io.emtfxml.metadata.helpers | _read_element | No declination in EMTF XML
# 24:10:08T13:06:22 | WARNING | line:256 |mtpy.core.mt_collection | add_tf | If you are adding multiple transfer functions, suggest making a list of transfer functions first then adding the list using mt_collection.add_tf([list_of_tfs]). Otherwise adding transfer functions one by one will be slow.
# 24:10:08T13:06:22 | WARNING | line:206 |mt_metadata.transfer_functions.tf.station | get_run | Could not find IDJ11a in runs.
# 24:10:08T13:06:22 | INFO | line:399 |mtpy.core.mt_collection | _from_mt_object | added Transportable_Array.IDJ11
# 24:10:08T13:06:22 | WARNING | line:84 |mt_metadata.transfer_functions.io.emtfxml.metadata.helpers | _read_element | No declination in EMTF XML
# 24:10:08T13:06:23 | WARNING | line:256 |mtpy.core.mt_collection | add_tf | If you are adding multiple transfer functions, suggest making a list of transfer functions first then adding the list using mt_collection.add_tf([list_of_tfs]). Otherwise adding transfer functions one by one will be slow.
# 24:10:08T13:06:23 | WARNING | line:206 |mt_metadata.transfer_functions.tf.station | get_run | Could not find IDJ12a in runs.
# 24:10:08T13:06:23 | INFO | line:399 |mtpy.core.mt_collection | _from_mt_object | added Transportable_Array.IDJ12
# 24:10:08T13:06:23 | WARNING | line:84 |mt_metadata.transfer_functions.io.emtfxml.metadata.helpers | _read_element | No declination in EMTF XML
# 24:10:08T13:06:23 | WARNING | line:256 |mtpy.core.mt_collection | add_tf | If you are adding multiple transfer functions, suggest making a list of transfer functions first then adding the list using mt_collection.add_tf([list_of_tfs]). Otherwise adding transfer functions one by one will be slow.
# 24:10:08T13:06:24 | INFO | line:399 |mtpy.core.mt_collection | _from_mt_object | added Transportable_Array.IDJ13
# 24:10:08T13:06:24 | WARNING | line:84 |mt_metadata.transfer_functions.io.emtfxml.metadata.helpers | _read_element | No declination in EMTF XML
# 24:10:08T13:06:24 | WARNING | line:256 |mtpy.core.mt_collection | add_tf | If you are adding multiple transfer functions, suggest making a list of transfer functions first then adding the list using mt_collection.add_tf([list_of_tfs]). Otherwise adding transfer functions one by one will be slow.
# 24:10:08T13:06:24 | WARNING | line:206 |mt_metadata.transfer_functions.tf.station | get_run | Could not find IDJ14a in runs.
# 24:10:08T13:06:24 | INFO | line:399 |mtpy.core.mt_collection | _from_mt_object | added Transportable_Array.IDJ14
# 24:10:08T13:06:25 | WARNING | line:84 |mt_metadata.transfer_functions.io.emtfxml.metadata.helpers | _read_element | No declination in EMTF XML
# 24:10:08T13:06:25 | WARNING | line:256 |mtpy.core.mt_collection | add_tf | If you are adding multiple transfer functions, suggest making a list of transfer functions first then adding the list using mt_collection.add_tf([list_of_tfs]). Otherwise adding transfer functions one by one will be slow.
# 24:10:08T13:06:25 | WARNING | line:206 |mt_metadata.transfer_functions.tf.station | get_run | Could not find IDJ15a in runs.
# 24:10:08T13:06:25 | INFO | line:399 |mtpy.core.mt_collection | _from_mt_object | added Transportable_Array.IDJ15
# 24:10:08T13:06:26 | WARNING | line:84 |mt_metadata.transfer_functions.io.emtfxml.metadata.helpers | _read_element | No declination in EMTF XML
# 24:10:08T13:06:26 | WARNING | line:256 |mtpy.core.mt_collection | add_tf | If you are adding multiple transfer functions, suggest making a list of transfer functions first then adding the list using mt_collection.add_tf([list_of_tfs]). Otherwise adding transfer functions one by one will be slow.
# 24:10:08T13:06:26 | WARNING | line:206 |mt_metadata.transfer_functions.tf.station | get_run | Could not find IDJ16b in runs.
# 24:10:08T13:06:26 | INFO | line:399 |mtpy.core.mt_collection | _from_mt_object | added Transportable_Array.IDJ16
# 24:10:08T13:06:26 | WARNING | line:84 |mt_metadata.transfer_functions.io.emtfxml.metadata.helpers | _read_element | No declination in EMTF XML
# 24:10:08T13:06:27 | WARNING | line:256 |mtpy.core.mt_collection | add_tf | If you are adding multiple transfer functions, suggest making a list of transfer functions first then adding the list using mt_collection.add_tf([list_of_tfs]). Otherwise adding transfer functions one by one will be slow.
# 24:10:08T13:06:27 | WARNING | line:206 |mt_metadata.transfer_functions.tf.station | get_run | Could not find IDK10a in runs.
# 24:10:08T13:06:27 | INFO | line:399 |mtpy.core.mt_collection | _from_mt_object | added Transportable_Array.IDK10
# 24:10:08T13:06:27 | WARNING | line:84 |mt_metadata.transfer_functions.io.emtfxml.metadata.helpers | _read_element | No declination in EMTF XML
# 24:10:08T13:06:27 | WARNING | line:256 |mtpy.core.mt_collection | add_tf | If you are adding multiple transfer functions, suggest making a list of transfer functions first then adding the list using mt_collection.add_tf([list_of_tfs]). Otherwise adding transfer functions one by one will be slow.
# 24:10:08T13:06:27 | WARNING | line:206 |mt_metadata.transfer_functions.tf.station | get_run | Could not find IDK11a in runs.
# 24:10:08T13:06:28 | INFO | line:399 |mtpy.core.mt_collection | _from_mt_object | added Transportable_Array.IDK11
# 24:10:08T13:06:28 | WARNING | line:84 |mt_metadata.transfer_functions.io.emtfxml.metadata.helpers | _read_element | No declination in EMTF XML
# 24:10:08T13:06:28 | WARNING | line:256 |mtpy.core.mt_collection | add_tf | If you are adding multiple transfer functions, suggest making a list of transfer functions first then adding the list using mt_collection.add_tf([list_of_tfs]). Otherwise adding transfer functions one by one will be slow.
# 24:10:08T13:06:28 | WARNING | line:206 |mt_metadata.transfer_functions.tf.station | get_run | Could not find IDK12b in runs.
# 24:10:08T13:06:28 | INFO | line:399 |mtpy.core.mt_collection | _from_mt_object | added Transportable_Array.IDK12
# 24:10:08T13:06:29 | WARNING | line:84 |mt_metadata.transfer_functions.io.emtfxml.metadata.helpers | _read_element | No declination in EMTF XML
# 24:10:08T13:06:29 | WARNING | line:256 |mtpy.core.mt_collection | add_tf | If you are adding multiple transfer functions, suggest making a list of transfer functions first then adding the list using mt_collection.add_tf([list_of_tfs]). Otherwise adding transfer functions one by one will be slow.
# 24:10:08T13:06:29 | WARNING | line:206 |mt_metadata.transfer_functions.tf.station | get_run | Could not find IDK13a in runs.
# 24:10:08T13:06:29 | INFO | line:399 |mtpy.core.mt_collection | _from_mt_object | added Transportable_Array.IDK13
# 24:10:08T13:06:30 | WARNING | line:84 |mt_metadata.transfer_functions.io.emtfxml.metadata.helpers | _read_element | No declination in EMTF XML
# 24:10:08T13:06:30 | WARNING | line:256 |mtpy.core.mt_collection | add_tf | If you are adding multiple transfer functions, suggest making a list of transfer functions first then adding the list using mt_collection.add_tf([list_of_tfs]). Otherwise adding transfer functions one by one will be slow.
# 24:10:08T13:06:30 | WARNING | line:206 |mt_metadata.transfer_functions.tf.station | get_run | Could not find IDK14d in runs.
# 24:10:08T13:06:30 | INFO | line:399 |mtpy.core.mt_collection | _from_mt_object | added Transportable_Array.IDK14
# 24:10:08T13:06:31 | WARNING | line:256 |mtpy.core.mt_collection | add_tf | If you are adding multiple transfer functions, suggest making a list of transfer functions first then adding the list using mt_collection.add_tf([list_of_tfs]). Otherwise adding transfer functions one by one will be slow.
# 24:10:08T13:06:31 | WARNING | line:206 |mt_metadata.transfer_functions.tf.station | get_run | Could not find IDK15a in runs.
# 24:10:08T13:06:31 | WARNING | line:206 |mt_metadata.transfer_functions.tf.station | get_run | Could not find IDK15b in runs.
# 24:10:08T13:06:31 | WARNING | line:206 |mt_metadata.transfer_functions.tf.station | get_run | Could not find IDK15e in runs.
# 24:10:08T13:06:31 | WARNING | line:206 |mt_metadata.transfer_functions.tf.station | get_run | Could not find IDK15m in runs.
# 24:10:08T13:06:31 | WARNING | line:206 |mt_metadata.transfer_functions.tf.station | get_run | Could not find IDK15n in runs.
# 24:10:08T13:06:31 | INFO | line:399 |mtpy.core.mt_collection | _from_mt_object | added Transportable_Array.IDK15
# 24:10:08T13:06:32 | WARNING | line:84 |mt_metadata.transfer_functions.io.emtfxml.metadata.helpers | _read_element | No declination in EMTF XML
# 24:10:08T13:06:32 | WARNING | line:256 |mtpy.core.mt_collection | add_tf | If you are adding multiple transfer functions, suggest making a list of transfer functions first then adding the list using mt_collection.add_tf([list_of_tfs]). Otherwise adding transfer functions one by one will be slow.
# 24:10:08T13:06:32 | WARNING | line:206 |mt_metadata.transfer_functions.tf.station | get_run | Could not find IDK16a in runs.
# 24:10:08T13:06:32 | WARNING | line:206 |mt_metadata.transfer_functions.tf.station | get_run | Could not find IDK16b in runs.
# 24:10:08T13:06:32 | WARNING | line:206 |mt_metadata.transfer_functions.tf.station | get_run | Could not find IDK16c in runs.
# 24:10:08T13:06:32 | INFO | line:399 |mtpy.core.mt_collection | _from_mt_object | added Transportable_Array.IDK16
# 24:10:08T13:06:33 | WARNING | line:84 |mt_metadata.transfer_functions.io.emtfxml.metadata.helpers | _read_element | No declination in EMTF XML
# 24:10:08T13:06:33 | WARNING | line:256 |mtpy.core.mt_collection | add_tf | If you are adding multiple transfer functions, suggest making a list of transfer functions first then adding the list using mt_collection.add_tf([list_of_tfs]). Otherwise adding transfer functions one by one will be slow.
# 24:10:08T13:06:33 | WARNING | line:206 |mt_metadata.transfer_functions.tf.station | get_run | Could not find IDL10a in runs.
# 24:10:08T13:06:33 | INFO | line:399 |mtpy.core.mt_collection | _from_mt_object | added Transportable_Array.IDL10
# 24:10:08T13:06:34 | WARNING | line:84 |mt_metadata.transfer_functions.io.emtfxml.metadata.helpers | _read_element | No declination in EMTF XML
# 24:10:08T13:06:34 | WARNING | line:256 |mtpy.core.mt_collection | add_tf | If you are adding multiple transfer functions, suggest making a list of transfer functions first then adding the list using mt_collection.add_tf([list_of_tfs]). Otherwise adding transfer functions one by one will be slow.
# 24:10:08T13:06:34 | WARNING | line:206 |mt_metadata.transfer_functions.tf.station | get_run | Could not find IDL11a in runs.
# 24:10:08T13:06:34 | INFO | line:399 |mtpy.core.mt_collection | _from_mt_object | added Transportable_Array.IDL11
# 24:10:08T13:06:34 | WARNING | line:84 |mt_metadata.transfer_functions.io.emtfxml.metadata.helpers | _read_element | No declination in EMTF XML
# 24:10:08T13:06:35 | WARNING | line:256 |mtpy.core.mt_collection | add_tf | If you are adding multiple transfer functions, suggest making a list of transfer functions first then adding the list using mt_collection.add_tf([list_of_tfs]). Otherwise adding transfer functions one by one will be slow.
# 24:10:08T13:06:35 | WARNING | line:206 |mt_metadata.transfer_functions.tf.station | get_run | Could not find IDL12a in runs.
# 24:10:08T13:06:35 | INFO | line:399 |mtpy.core.mt_collection | _from_mt_object | added Transportable_Array.IDL12
# 24:10:08T13:06:35 | WARNING | line:84 |mt_metadata.transfer_functions.io.emtfxml.metadata.helpers | _read_element | No declination in EMTF XML
# 24:10:08T13:06:36 | WARNING | line:256 |mtpy.core.mt_collection | add_tf | If you are adding multiple transfer functions, suggest making a list of transfer functions first then adding the list using mt_collection.add_tf([list_of_tfs]). Otherwise adding transfer functions one by one will be slow.
# 24:10:08T13:06:36 | WARNING | line:206 |mt_metadata.transfer_functions.tf.station | get_run | Could not find IDL13a in runs.
# 24:10:08T13:06:36 | INFO | line:399 |mtpy.core.mt_collection | _from_mt_object | added Transportable_Array.IDL13
# 24:10:08T13:06:36 | WARNING | line:84 |mt_metadata.transfer_functions.io.emtfxml.metadata.helpers | _read_element | No declination in EMTF XML
# 24:10:08T13:06:36 | WARNING | line:256 |mtpy.core.mt_collection | add_tf | If you are adding multiple transfer functions, suggest making a list of transfer functions first then adding the list using mt_collection.add_tf([list_of_tfs]). Otherwise adding transfer functions one by one will be slow.
# 24:10:08T13:06:37 | WARNING | line:206 |mt_metadata.transfer_functions.tf.station | get_run | Could not find IDL14a in runs.
# 24:10:08T13:06:37 | INFO | line:399 |mtpy.core.mt_collection | _from_mt_object | added Transportable_Array.IDL14
# 24:10:08T13:06:37 | WARNING | line:84 |mt_metadata.transfer_functions.io.emtfxml.metadata.helpers | _read_element | No declination in EMTF XML
# 24:10:08T13:06:37 | WARNING | line:256 |mtpy.core.mt_collection | add_tf | If you are adding multiple transfer functions, suggest making a list of transfer functions first then adding the list using mt_collection.add_tf([list_of_tfs]). Otherwise adding transfer functions one by one will be slow.
# 24:10:08T13:06:37 | WARNING | line:206 |mt_metadata.transfer_functions.tf.station | get_run | Could not find IDL15a in runs.
# 24:10:08T13:06:38 | INFO | line:399 |mtpy.core.mt_collection | _from_mt_object | added Transportable_Array.IDL15
# 24:10:08T13:06:38 | WARNING | line:84 |mt_metadata.transfer_functions.io.emtfxml.metadata.helpers | _read_element | No declination in EMTF XML
# 24:10:08T13:06:38 | WARNING | line:256 |mtpy.core.mt_collection | add_tf | If you are adding multiple transfer functions, suggest making a list of transfer functions first then adding the list using mt_collection.add_tf([list_of_tfs]). Otherwise adding transfer functions one by one will be slow.
# 24:10:08T13:06:38 | WARNING | line:206 |mt_metadata.transfer_functions.tf.station | get_run | Could not find IDL16c in runs.
# 24:10:08T13:06:38 | WARNING | line:206 |mt_metadata.transfer_functions.tf.station | get_run | Could not find IDL16d in runs.
# 24:10:08T13:06:39 | WARNING | line:206 |mt_metadata.transfer_functions.tf.station | get_run | Could not find IDL16g in runs.
# 24:10:08T13:06:39 | WARNING | line:206 |mt_metadata.transfer_functions.tf.station | get_run | Could not find IDL16h in runs.
# 24:10:08T13:06:39 | INFO | line:399 |mtpy.core.mt_collection | _from_mt_object | added Transportable_Array.IDL16
# 24:10:08T13:06:39 | WARNING | line:256 |mtpy.core.mt_collection | add_tf | If you are adding multiple transfer functions, suggest making a list of transfer functions first then adding the list using mt_collection.add_tf([list_of_tfs]). Otherwise adding transfer functions one by one will be slow.
# 24:10:08T13:06:39 | WARNING | line:206 |mt_metadata.transfer_functions.tf.station | get_run | Could not find M2E13a in runs.
# 24:10:08T13:06:40 | INFO | line:399 |mtpy.core.mt_collection | _from_mt_object | added Transportable_Array.M2E13
# 24:10:08T13:06:40 | WARNING | line:256 |mtpy.core.mt_collection | add_tf | If you are adding multiple transfer functions, suggest making a list of transfer functions first then adding the list using mt_collection.add_tf([list_of_tfs]). Otherwise adding transfer functions one by one will be slow.
# 24:10:08T13:06:40 | INFO | line:399 |mtpy.core.mt_collection | _from_mt_object | added Transportable_Array.MTD13
# 24:10:08T13:06:41 | WARNING | line:84 |mt_metadata.transfer_functions.io.emtfxml.metadata.helpers | _read_element | No declination in EMTF XML
# ...
# 24:10:08T13:08:59 | WARNING | line:256 |mtpy.core.mt_collection | add_tf | If you are adding multiple transfer functions, suggest making a list of transfer functions first then adding the list using mt_collection.add_tf([list_of_tfs]). Otherwise adding transfer functions one by one will be slow.
# 24:10:08T13:08:59 | INFO | line:399 |mtpy.core.mt_collection | _from_mt_object | added Yellowstone-Snake_River_Plain.SR232
# 24:10:08T13:09:00 | WARNING | line:84 |mt_metadata.transfer_functions.io.emtfxml.metadata.helpers | _read_element | No declination in EMTF XML
# 24:10:08T13:09:00 | WARNING | line:256 |mtpy.core.mt_collection | add_tf | If you are adding multiple transfer functions, suggest making a list of transfer functions first then adding the list using mt_collection.add_tf([list_of_tfs]). Otherwise adding transfer functions one by one will be slow.
# 24:10:08T13:09:00 | INFO | line:399 |mtpy.core.mt_collection | _from_mt_object | added Yellowstone-Snake_River_Plain.SR236
# 24:10:08T13:09:01 | WARNING | line:84 |mt_metadata.transfer_functions.io.emtfxml.metadata.helpers | _read_element | No declination in EMTF XML
# 24:10:08T13:09:01 | WARNING | line:256 |mtpy.core.mt_collection | add_tf | If you are adding multiple transfer functions, suggest making a list of transfer functions first then adding the list using mt_collection.add_tf([list_of_tfs]). Otherwise adding transfer functions one by one will be slow.
# 24:10:08T13:09:02 | INFO | line:399 |mtpy.core.mt_collection | _from_mt_object | added Yellowstone-Snake_River_Plain.SR238
# 24:10:08T13:09:03 | WARNING | line:84 |mt_metadata.transfer_functions.io.emtfxml.metadata.helpers | _read_element | No declination in EMTF XML
# 24:10:08T13:09:03 | WARNING | line:256 |mtpy.core.mt_collection | add_tf | If you are adding multiple transfer functions, suggest making a list of transfer functions first then adding the list using mt_collection.add_tf([list_of_tfs]). Otherwise adding transfer functions one by one will be slow.
# 24:10:08T13:09:03 | INFO | line:399 |mtpy.core.mt_collection | _from_mt_object | added Yellowstone-Snake_River_Plain.SR240
# 24:10:08T13:09:04 | WARNING | line:84 |mt_metadata.transfer_functions.io.emtfxml.metadata.helpers | _read_element | No declination in EMTF XML
# 24:10:08T13:09:05 | WARNING | line:256 |mtpy.core.mt_collection | add_tf | If you are adding multiple transfer functions, suggest making a list of transfer functions first then adding the list using mt_collection.add_tf([list_of_tfs]). Otherwise adding transfer functions one by one will be slow.
# 24:10:08T13:09:05 | INFO | line:399 |mtpy.core.mt_collection | _from_mt_object | added Yellowstone-Snake_River_Plain.SR244
# 24:10:08T13:09:06 | WARNING | line:84 |mt_metadata.transfer_functions.io.emtfxml.metadata.helpers | _read_element | No declination in EMTF XML
# 24:10:08T13:09:06 | WARNING | line:256 |mtpy.core.mt_collection | add_tf | If you are adding multiple transfer functions, suggest making a list of transfer functions first then adding the list using mt_collection.add_tf([list_of_tfs]). Otherwise adding transfer functions one by one will be slow.
# 24:10:08T13:09:06 | WARNING | line:206 |mt_metadata.transfer_functions.tf.station | get_run | Could not find SR247d in runs.
# 24:10:08T13:09:06 | INFO | line:399 |mtpy.core.mt_collection | _from_mt_object | added Yellowstone-Snake_River_Plain.SR247
# 24:10:08T13:09:07 | WARNING | line:84 |mt_metadata.transfer_functions.io.emtfxml.metadata.helpers | _read_element | No declination in EMTF XML
# 24:10:08T13:09:08 | WARNING | line:256 |mtpy.core.mt_collection | add_tf | If you are adding multiple transfer functions, suggest making a list of transfer functions first then adding the list using mt_collection.add_tf([list_of_tfs]). Otherwise adding transfer functions one by one will be slow.
# 24:10:08T13:09:08 | INFO | line:399 |mtpy.core.mt_collection | _from_mt_object | added Yellowstone-Snake_River_Plain.SR250
# 24:10:08T13:09:09 | WARNING | line:84 |mt_metadata.transfer_functions.io.emtfxml.metadata.helpers | _read_element | No declination in EMTF XML
# 24:10:08T13:09:09 | WARNING | line:256 |mtpy.core.mt_collection | add_tf | If you are adding multiple transfer functions, suggest making a list of transfer functions first then adding the list using mt_collection.add_tf([list_of_tfs]). Otherwise adding transfer functions one by one will be slow.
# 24:10:08T13:09:09 | INFO | line:399 |mtpy.core.mt_collection | _from_mt_object | added Yellowstone-Snake_River_Plain.SR252
# 24:10:08T13:09:10 | WARNING | line:84 |mt_metadata.transfer_functions.io.emtfxml.metadata.helpers | _read_element | No declination in EMTF XML
# 24:10:08T13:09:10 | WARNING | line:256 |mtpy.core.mt_collection | add_tf | If you are adding multiple transfer functions, suggest making a list of transfer functions first then adding the list using mt_collection.add_tf([list_of_tfs]). Otherwise adding transfer functions one by one will be slow.
# 24:10:08T13:09:11 | INFO | line:399 |mtpy.core.mt_collection | _from_mt_object | added Yellowstone-Snake_River_Plain.SR255
# 24:10:08T13:09:12 | WARNING | line:84 |mt_metadata.transfer_functions.io.emtfxml.metadata.helpers | _read_element | No declination in EMTF XML
# 24:10:08T13:09:12 | WARNING | line:256 |mtpy.core.mt_collection | add_tf | If you are adding multiple transfer functions, suggest making a list of transfer functions first then adding the list using mt_collection.add_tf([list_of_tfs]). Otherwise adding transfer functions one by one will be slow.
# 24:10:08T13:09:12 | INFO | line:399 |mtpy.core.mt_collection | _from_mt_object | added Yellowstone-Snake_River_Plain.SR258
# 24:10:08T13:09:13 | WARNING | line:84 |mt_metadata.transfer_functions.io.emtfxml.metadata.helpers | _read_element | No declination in EMTF XML
# 24:10:08T13:09:14 | WARNING | line:256 |mtpy.core.mt_collection | add_tf | If you are adding multiple transfer functions, suggest making a list of transfer functions first then adding the list using mt_collection.add_tf([list_of_tfs]). Otherwise adding transfer functions one by one will be slow.
# 24:10:08T13:09:14 | INFO | line:399 |mtpy.core.mt_collection | _from_mt_object | added Yellowstone-Snake_River_Plain.SR264
# 24:10:08T13:09:15 | WARNING | line:84 |mt_metadata.transfer_functions.io.emtfxml.metadata.helpers | _read_element | No declination in EMTF XML
# 24:10:08T13:09:15 | WARNING | line:256 |mtpy.core.mt_collection | add_tf | If you are adding multiple transfer functions, suggest making a list of transfer functions first then adding the list using mt_collection.add_tf([list_of_tfs]). Otherwise adding transfer functions one by one will be slow.
# 24:10:08T13:09:15 | INFO | line:399 |mtpy.core.mt_collection | _from_mt_object | added Yellowstone-Snake_River_Plain.SR265
# 24:10:08T13:09:16 | WARNING | line:84 |mt_metadata.transfer_functions.io.emtfxml.metadata.helpers | _read_element | No declination in EMTF XML
# 24:10:08T13:09:17 | WARNING | line:256 |mtpy.core.mt_collection | add_tf | If you are adding multiple transfer functions, suggest making a list of transfer functions first then adding the list using mt_collection.add_tf([list_of_tfs]). Otherwise adding transfer functions one by one will be slow.
# 24:10:08T13:09:17 | INFO | line:399 |mtpy.core.mt_collection | _from_mt_object | added Yellowstone-Snake_River_Plain.SR270
# 24:10:08T13:09:18 | WARNING | line:84 |mt_metadata.transfer_functions.io.emtfxml.metadata.helpers | _read_element | No declination in EMTF XML
# 24:10:08T13:09:18 | WARNING | line:256 |mtpy.core.mt_collection | add_tf | If you are adding multiple transfer functions, suggest making a list of transfer functions first then adding the list using mt_collection.add_tf([list_of_tfs]). Otherwise adding transfer functions one by one will be slow.
# 24:10:08T13:09:18 | INFO | line:399 |mtpy.core.mt_collection | _from_mt_object | added Yellowstone-Snake_River_Plain.SR271
# 24:10:08T13:09:19 | WARNING | line:84 |mt_metadata.transfer_functions.io.emtfxml.metadata.helpers | _read_element | No declination in EMTF XML
# 24:10:08T13:09:20 | WARNING | line:256 |mtpy.core.mt_collection | add_tf | If you are adding multiple transfer functions, suggest making a list of transfer functions first then adding the list using mt_collection.add_tf([list_of_tfs]). Otherwise adding transfer functions one by one will be slow.
# 24:10:08T13:09:20 | INFO | line:399 |mtpy.core.mt_collection | _from_mt_object | added Yellowstone-Snake_River_Plain.SR274
# 24:10:08T13:09:21 | WARNING | line:84 |mt_metadata.transfer_functions.io.emtfxml.metadata.helpers | _read_element | No declination in EMTF XML
# 24:10:08T13:09:21 | WARNING | line:256 |mtpy.core.mt_collection | add_tf | If you are adding multiple transfer functions, suggest making a list of transfer functions first then adding the list using mt_collection.add_tf([list_of_tfs]). Otherwise adding transfer functions one by one will be slow.
# 24:10:08T13:09:21 | INFO | line:399 |mtpy.core.mt_collection | _from_mt_object | added Yellowstone-Snake_River_Plain.SR278
# 24:10:08T13:09:22 | WARNING | line:84 |mt_metadata.transfer_functions.io.emtfxml.metadata.helpers | _read_element | No declination in EMTF XML
# 24:10:08T13:09:23 | WARNING | line:256 |mtpy.core.mt_collection | add_tf | If you are adding multiple transfer functions, suggest making a list of transfer functions first then adding the list using mt_collection.add_tf([list_of_tfs]). Otherwise adding transfer functions one by one will be slow.
# 24:10:08T13:09:23 | INFO | line:399 |mtpy.core.mt_collection | _from_mt_object | added Yellowstone-Snake_River_Plain.SR280
# 24:10:08T13:09:24 | WARNING | line:84 |mt_metadata.transfer_functions.io.emtfxml.metadata.helpers | _read_element | No declination in EMTF XML
# 24:10:08T13:09:24 | WARNING | line:256 |mtpy.core.mt_collection | add_tf | If you are adding multiple transfer functions, suggest making a list of transfer functions first then adding the list using mt_collection.add_tf([list_of_tfs]). Otherwise adding transfer functions one by one will be slow.
# 24:10:08T13:09:24 | INFO | line:399 |mtpy.core.mt_collection | _from_mt_object | added Yellowstone-Snake_River_Plain.SR282
# 24:10:08T13:09:26 | WARNING | line:84 |mt_metadata.transfer_functions.io.emtfxml.metadata.helpers | _read_element | No declination in EMTF XML
# 24:10:08T13:09:26 | WARNING | line:256 |mtpy.core.mt_collection | add_tf | If you are adding multiple transfer functions, suggest making a list of transfer functions first then adding the list using mt_collection.add_tf([list_of_tfs]). Otherwise adding transfer functions one by one will be slow.
# 24:10:08T13:09:26 | INFO | line:399 |mtpy.core.mt_collection | _from_mt_object | added Yellowstone-Snake_River_Plain.SR286
# 24:10:08T13:09:27 | WARNING | line:84 |mt_metadata.transfer_functions.io.emtfxml.metadata.helpers | _read_element | No declination in EMTF XML
# 24:10:08T13:09:27 | WARNING | line:256 |mtpy.core.mt_collection | add_tf | If you are adding multiple transfer functions, suggest making a list of transfer functions first then adding the list using mt_collection.add_tf([list_of_tfs]). Otherwise adding transfer functions one by one will be slow.
# 24:10:08T13:09:27 | INFO | line:399 |mtpy.core.mt_collection | _from_mt_object | added Yellowstone-Snake_River_Plain.SR290
# 24:10:08T13:09:29 | WARNING | line:84 |mt_metadata.transfer_functions.io.emtfxml.metadata.helpers | _read_element | No declination in EMTF XML
# 24:10:08T13:09:29 | WARNING | line:256 |mtpy.core.mt_collection | add_tf | If you are adding multiple transfer functions, suggest making a list of transfer functions first then adding the list using mt_collection.add_tf([list_of_tfs]). Otherwise adding transfer functions one by one will be slow.
# 24:10:08T13:09:29 | WARNING | line:206 |mt_metadata.transfer_functions.tf.station | get_run | Could not find SR910f in runs.
# 24:10:08T13:09:29 | INFO | line:399 |mtpy.core.mt_collection | _from_mt_object | added Yellowstone-Snake_River_Plain.SR910
# 24:10:08T13:09:30 | WARNING | line:84 |mt_metadata.transfer_functions.io.emtfxml.metadata.helpers | _read_element | No declination in EMTF XML
# 24:10:08T13:09:30 | WARNING | line:256 |mtpy.core.mt_collection | add_tf | If you are adding multiple transfer functions, suggest making a list of transfer functions first then adding the list using mt_collection.add_tf([list_of_tfs]). Otherwise adding transfer functions one by one will be slow.
# 24:10:08T13:09:30 | WARNING | line:206 |mt_metadata.transfer_functions.tf.station | get_run | Could not find SR920f in runs.
# 24:10:08T13:09:31 | INFO | line:399 |mtpy.core.mt_collection | _from_mt_object | added Yellowstone-Snake_River_Plain.SR920
# 24:10:08T13:09:32 | WARNING | line:84 |mt_metadata.transfer_functions.io.emtfxml.metadata.helpers | _read_element | No declination in EMTF XML
# 24:10:08T13:09:32 | WARNING | line:256 |mtpy.core.mt_collection | add_tf | If you are adding multiple transfer functions, suggest making a list of transfer functions first then adding the list using mt_collection.add_tf([list_of_tfs]). Otherwise adding transfer functions one by one will be slow.
# 24:10:08T13:09:32 | INFO | line:399 |mtpy.core.mt_collection | _from_mt_object | added Yellowstone-Snake_River_Plain.SR930
# 24:10:08T13:09:33 | WARNING | line:84 |mt_metadata.transfer_functions.io.emtfxml.metadata.helpers | _read_element | No declination in EMTF XML
# 24:10:08T13:09:34 | WARNING | line:256 |mtpy.core.mt_collection | add_tf | If you are adding multiple transfer functions, suggest making a list of transfer functions first then adding the list using mt_collection.add_tf([list_of_tfs]). Otherwise adding transfer functions one by one will be slow.
# 24:10:08T13:09:34 | WARNING | line:206 |mt_metadata.transfer_functions.tf.station | get_run | Could not find SR954f in runs.
# 24:10:08T13:09:34 | INFO | line:399 |mtpy.core.mt_collection | _from_mt_object | added Yellowstone-Snake_River_Plain.SR954
# 24:10:08T13:09:35 | WARNING | line:84 |mt_metadata.transfer_functions.io.emtfxml.metadata.helpers | _read_element | No declination in EMTF XML
# 24:10:08T13:09:35 | WARNING | line:256 |mtpy.core.mt_collection | add_tf | If you are adding multiple transfer functions, suggest making a list of transfer functions first then adding the list using mt_collection.add_tf([list_of_tfs]). Otherwise adding transfer functions one by one will be slow.
# 24:10:08T13:09:35 | WARNING | line:206 |mt_metadata.transfer_functions.tf.station | get_run | Could not find SR966f in runs.
# 24:10:08T13:09:35 | INFO | line:399 |mtpy.core.mt_collection | _from_mt_object | added Yellowstone-Snake_River_Plain.SR966
# 24:10:08T13:09:37 | WARNING | line:84 |mt_metadata.transfer_functions.io.emtfxml.metadata.helpers | _read_element | No declination in EMTF XML
# 24:10:08T13:09:37 | WARNING | line:256 |mtpy.core.mt_collection | add_tf | If you are adding multiple transfer functions, suggest making a list of transfer functions first then adding the list using mt_collection.add_tf([list_of_tfs]). Otherwise adding transfer functions one by one will be slow.
# 24:10:08T13:09:37 | INFO | line:399 |mtpy.core.mt_collection | _from_mt_object | added Yellowstone-Snake_River_Plain.SR980
# 24:10:08T13:09:38 | WARNING | line:84 |mt_metadata.transfer_functions.io.emtfxml.metadata.helpers | _read_element | No declination in EMTF XML
# 24:10:08T13:09:38 | WARNING | line:256 |mtpy.core.mt_collection | add_tf | If you are adding multiple transfer functions, suggest making a list of transfer functions first then adding the list using mt_collection.add_tf([list_of_tfs]). Otherwise adding transfer functions one by one will be slow.
# 24:10:08T13:09:39 | INFO | line:399 |mtpy.core.mt_collection | _from_mt_object | added Yellowstone-Snake_River_Plain.SR990
# 24:10:08T13:09:48 | INFO | line:777 |mth5.mth5 | close_mth5 | Flushing and closing c:\Users\jpeacock\OneDrive - DOI\Documents\GitHub\iris-mt-course-2022\data\transfer_functions\yellowstone_mt_collection_03.h5
# CPU times: total: 3min 20s
# Wall time: 3min 56s

# %% [markdown]
# ### Make sure everything loaded in properly
#
# We want to make sure everything loaded in properly.  `MTCollection` has a convenient property called `dataframe` this will list all transfer functions found in the MTH5 file.
#
# **Note:** This is a property that when called returns a summary of all transfer functions contained in the MTH5 at the point that it is called.  Therefore, if you update the file by adding a transfer function and then calle `dataframe` you will get an updated summary.  There is more we can do with `dataframe` which we will look at in a later lesson.

# %%
tf_df
# Out:
#     station                         survey   latitude   longitude  elevation  \
# 0     IDD11            Transportable_Array  47.043986 -116.345982    850.750
# 1     IDD12            Transportable_Array  47.047800 -115.348000   1137.862
# 2     IDE11            Transportable_Array  46.353000 -116.212965    882.625
# 3     IDE12            Transportable_Array  46.387100 -115.582000   1633.900
# 4     IDF11            Transportable_Array  45.889496 -116.157113   1175.550
# ..      ...                            ...        ...         ...        ...
# 216   SR930  Yellowstone-Snake_River_Plain  43.188800 -113.042300   1568.050
# 217   SR954  Yellowstone-Snake_River_Plain  43.689700 -112.375700   1536.925
# 218   SR966  Yellowstone-Snake_River_Plain  43.948300 -112.039000   1486.875
# 219   SR980  Yellowstone-Snake_River_Plain  44.258100 -111.553000   2075.900
# 220   SR990  Yellowstone-Snake_River_Plain  44.463100 -111.228700   1979.200
#
#      tf_id units  has_impedance  has_tipper  has_covariance  period_min  \
# 0    IDD11  none           True        True            True     7.31429
# 1    IDD12  none           True        True            True     7.31429
# 2    IDE11  none           True        True            True     7.31429
# 3    IDE12  none           True        True            True     7.31429
# 4    IDF11  none           True        True            True     7.31429
# ..     ...   ...            ...         ...             ...         ...
# 216  SR930  none           True        True            True     7.31429
# 217  SR954  none           True        True            True     7.31429
# 218  SR966  none           True        True            True     7.31429
# 219  SR980  none           True        True            True     7.31429
# 220  SR990  none           True        True            True     7.31429
#
#      period_max           hdf5_reference   station_hdf5_reference
# 0      18724.57  <HDF5 object reference>  <HDF5 object reference>
# 1      18724.57  <HDF5 object reference>  <HDF5 object reference>
# 2      18724.57  <HDF5 object reference>  <HDF5 object reference>
# 3      18724.57  <HDF5 object reference>  <HDF5 object reference>
# 4      18724.57  <HDF5 object reference>  <HDF5 object reference>
# ..          ...                      ...                      ...
# 216    18724.57  <HDF5 object reference>  <HDF5 object reference>
# 217    18724.57  <HDF5 object reference>  <HDF5 object reference>
# 218    18724.57  <HDF5 object reference>  <HDF5 object reference>
# 219    18724.57  <HDF5 object reference>  <HDF5 object reference>
# 220    18724.57  <HDF5 object reference>  <HDF5 object reference>
#
# [221 rows x 14 columns]

# %%
tf_df.survey.unique()
# Out:
# array(['Transportable_Array', 'YSBB', 'Yellowstone-Snake_River_Plain'],
#       dtype=object)

# %% [markdown]
# ## Next Example
#
# In the next we will have a look at the various plotting functions `MTCollection` has and how to use them.
